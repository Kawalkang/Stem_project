# %%
# Libraries
import pandas as pd
import numpy as np

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import f_oneway
from scipy.stats import chi2_contingency

from sklearn.utils import resample
import statsmodels.api as sm;
import scipy;
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


'''Font colors'''
#from pyfiglet import Figlet
#from termcolor import colored


#''Extra Libraries''

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.linear_model import LogisticRegression
#from sklearn.linear_model import RandomizedLasso,LassoLarsCV
from sklearn.exceptions import ConvergenceWarning 
from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer, accuracy_score, confusion_matrix
import sklearn.datasets 
'''Scipy, Stats Library'''
from scipy.stats import skew
''' To Ignore Warning'''
import warnings
warnings.filterwarnings('ignore')
''' To Do : Inline Priting of Visualizations '''
sns.set()
# %matplotlib inline

# %%
df1 = pd.read_excel('PossessionSummary_Match_April_01.xlsx')
df1.columns=df1.iloc[5]
df1=df1[6:542]
df1
# Out:
# 5       Season      Date   Weekday       Start Time Session Type Session Id  \
# 6    2023/2024  01/04/23  Saturday  14:48:39 GMT+13        Match    1687019
# 7    2023/2024  01/04/23  Saturday  14:48:39 GMT+13        Match    1687019
# 8    2023/2024  01/04/23  Saturday  14:48:39 GMT+13        Match    1687019
# 9    2023/2024  01/04/23  Saturday  14:48:39 GMT+13        Match    1687019
# 10   2023/2024  01/04/23  Saturday  14:48:39 GMT+13        Match    1687019
# ..         ...       ...       ...              ...          ...        ...
# 537  2023/2024  01/04/23  Saturday  14:48:39 GMT+13        Match    1687019
# 538  2023/2024  01/04/23  Saturday  14:48:39 GMT+13        Match    1687019
# 539  2023/2024  01/04/23  Saturday  14:48:39 GMT+13        Match    1687019
# 540  2023/2024  01/04/23  Saturday  14:48:39 GMT+13        Match    1687019
# 541  2023/2024  01/04/23  Saturday  14:48:39 GMT+13        Match    1687019
#
# ...

# %%
df2 = pd.read_excel('PossessionSummary_Match_April_07.xlsx')
df2.columns=df2.iloc[5]
df2=df2[6:612]
df2
# Out:
# 5       Season      Date Weekday       Start Time Session Type Session Id  \
# 6    2023/2024  07/04/23  Friday  11:13:49 GMT+12        Match    1705066
# 7    2023/2024  07/04/23  Friday  11:13:49 GMT+12        Match    1705066
# 8    2023/2024  07/04/23  Friday  11:13:49 GMT+12        Match    1705066
# 9    2023/2024  07/04/23  Friday  11:13:49 GMT+12        Match    1705066
# 10   2023/2024  07/04/23  Friday  11:13:49 GMT+12        Match    1705066
# ..         ...       ...     ...              ...          ...        ...
# 607  2023/2024  07/04/23  Friday  11:13:49 GMT+12        Match    1705066
# 608  2023/2024  07/04/23  Friday  11:13:49 GMT+12        Match    1705066
# 609  2023/2024  07/04/23  Friday  11:13:49 GMT+12        Match    1705066
# 610  2023/2024  07/04/23  Friday  11:13:49 GMT+12        Match    1705066
# 611  2023/2024  07/04/23  Friday  11:13:49 GMT+12        Match    1705066
#
# 5   Phase Type  Tag Phase Id Phase Start Time  ...      Player Name  \
# ...

# %%
df3 = pd.read_excel('PossessionSummary_Match_April_22.xlsx')
df3.columns=df3.iloc[5]
df3=df3[6:478]
df3
# Out:
# 5       Season      Date   Weekday       Start Time Session Type Session Id  \
# 6    2023/2024  22/04/23  Saturday  13:51:39 GMT+12        Match    1743402
# 7    2023/2024  22/04/23  Saturday  13:51:39 GMT+12        Match    1743402
# 8    2023/2024  22/04/23  Saturday  13:51:39 GMT+12        Match    1743402
# 9    2023/2024  22/04/23  Saturday  13:51:39 GMT+12        Match    1743402
# 10   2023/2024  22/04/23  Saturday  13:51:39 GMT+12        Match    1743402
# ..         ...       ...       ...              ...          ...        ...
# 473  2023/2024  22/04/23  Saturday  13:51:39 GMT+12        Match    1743402
# 474  2023/2024  22/04/23  Saturday  13:51:39 GMT+12        Match    1743402
# 475  2023/2024  22/04/23  Saturday  13:51:39 GMT+12        Match    1743402
# 476  2023/2024  22/04/23  Saturday  13:51:39 GMT+12        Match    1743402
# 477  2023/2024  22/04/23  Saturday  13:51:39 GMT+12        Match    1743402
#
# ...

# %%
df4 = pd.read_excel('PossessionSummary_Match_April_29.xlsx')
df4.columns=df4.iloc[5]
df4=df4[6:486]
df4
# Out:
# 5       Season      Date   Weekday       Start Time Session Type Session Id  \
# 6    2023/2024  29/04/23  Saturday  11:32:35 GMT+12        Match    1764288
# 7    2023/2024  29/04/23  Saturday  11:32:35 GMT+12        Match    1764288
# 8    2023/2024  29/04/23  Saturday  11:32:35 GMT+12        Match    1764288
# 9    2023/2024  29/04/23  Saturday  11:32:35 GMT+12        Match    1764288
# 10   2023/2024  29/04/23  Saturday  11:32:35 GMT+12        Match    1764288
# ..         ...       ...       ...              ...          ...        ...
# 481  2023/2024  29/04/23  Saturday  11:32:35 GMT+12        Match    1764288
# 482  2023/2024  29/04/23  Saturday  11:32:35 GMT+12        Match    1764288
# 483  2023/2024  29/04/23  Saturday  11:32:35 GMT+12        Match    1764288
# 484  2023/2024  29/04/23  Saturday  11:32:35 GMT+12        Match    1764288
# 485  2023/2024  29/04/23  Saturday  11:32:35 GMT+12        Match    1764288
#
# ...

# %%
df5 = pd.read_excel('PossessionSummary_Match_February_26.xlsx')
df5.columns=df5.iloc[5]
df5=df5[6:445]
df5
# Out:
# 5       Season      Date Weekday       Start Time Session Type Session Id  \
# 6    2023/2024  26/02/23  Sunday  15:22:40 GMT+13        Match    1591184
# 7    2023/2024  26/02/23  Sunday  15:22:40 GMT+13        Match    1591184
# 8    2023/2024  26/02/23  Sunday  15:22:40 GMT+13        Match    1591184
# 9    2023/2024  26/02/23  Sunday  15:22:40 GMT+13        Match    1591184
# 10   2023/2024  26/02/23  Sunday  15:22:40 GMT+13        Match    1591184
# ..         ...       ...     ...              ...          ...        ...
# 440  2023/2024  26/02/23  Sunday  15:22:40 GMT+13        Match    1591184
# 441  2023/2024  26/02/23  Sunday  15:22:40 GMT+13        Match    1591184
# 442  2023/2024  26/02/23  Sunday  15:22:40 GMT+13        Match    1591184
# 443  2023/2024  26/02/23  Sunday  15:22:40 GMT+13        Match    1591184
# 444  2023/2024  26/02/23  Sunday  15:22:40 GMT+13        Match    1591184
#
# 5   Phase Type  Tag Phase Id Phase Start Time  ...      Player Name  \
# ...

# %%
df6 = pd.read_excel('PossessionSummary_Match_July_01.xlsx')
df6.columns=df6.iloc[5]
df6=df6[6:420]
df6
# Out:
# 5       Season      Date   Weekday       Start Time Session Type Session Id  \
# 6    2023/2024  01/07/23  Saturday  12:28:24 GMT+12        Match    1889056
# 7    2023/2024  01/07/23  Saturday  12:28:24 GMT+12        Match    1889056
# 8    2023/2024  01/07/23  Saturday  12:28:24 GMT+12        Match    1889056
# 9    2023/2024  01/07/23  Saturday  12:28:24 GMT+12        Match    1889056
# 10   2023/2024  01/07/23  Saturday  12:28:24 GMT+12        Match    1889056
# ..         ...       ...       ...              ...          ...        ...
# 415  2023/2024  01/07/23  Saturday  12:28:24 GMT+12        Match    1889056
# 416  2023/2024  01/07/23  Saturday  12:28:24 GMT+12        Match    1889056
# 417  2023/2024  01/07/23  Saturday  12:28:24 GMT+12        Match    1889056
# 418  2023/2024  01/07/23  Saturday  12:28:24 GMT+12        Match    1889056
# 419  2023/2024  01/07/23  Saturday  12:28:24 GMT+12        Match    1889056
#
# ...

# %%
df7 = pd.read_excel('PossessionSummary_Match_July_14.xlsx')
df7.columns=df7.iloc[5]
df7=df7[6:606]
df7
# Out:
# 5       Season      Date Weekday       Start Time Session Type Session Id  \
# 6    2023/2024  14/07/23  Friday  12:19:41 GMT+12        Match    1905337
# 7    2023/2024  14/07/23  Friday  12:19:41 GMT+12        Match    1905337
# 8    2023/2024  14/07/23  Friday  12:19:41 GMT+12        Match    1905337
# 9    2023/2024  14/07/23  Friday  12:19:41 GMT+12        Match    1905337
# 10   2023/2024  14/07/23  Friday  12:19:41 GMT+12        Match    1905337
# ..         ...       ...     ...              ...          ...        ...
# 601  2023/2024  14/07/23  Friday  12:19:41 GMT+12        Match    1905337
# 602  2023/2024  14/07/23  Friday  12:19:41 GMT+12        Match    1905337
# 603  2023/2024  14/07/23  Friday  12:19:41 GMT+12        Match    1905337
# 604  2023/2024  14/07/23  Friday  12:19:41 GMT+12        Match    1905337
# 605  2023/2024  14/07/23  Friday  12:19:41 GMT+12        Match    1905337
#
# 5   Phase Type  Tag Phase Id Phase Start Time  ...           Player Name  \
# ...

# %%
df8 = pd.read_excel('PossessionSummary_Match_July_22.xlsx')
df8.columns=df8.iloc[5]
df8=df8[6:2357]
df8
# Out:
# 5        Season      Date   Weekday       Start Time Session Type Session Id  \
# 6     2023/2024  22/07/23  Saturday  11:21:08 GMT+12        Match    1917443
# 7     2023/2024  22/07/23  Saturday  11:21:08 GMT+12        Match    1917443
# 8     2023/2024  22/07/23  Saturday  11:21:08 GMT+12        Match    1917443
# 9     2023/2024  22/07/23  Saturday  11:21:08 GMT+12        Match    1917443
# 10    2023/2024  22/07/23  Saturday  11:21:08 GMT+12        Match    1917443
# ...         ...       ...       ...              ...          ...        ...
# 2352  2023/2024  22/07/23  Saturday  11:21:08 GMT+12        Match    1917443
# 2353  2023/2024  22/07/23  Saturday  11:21:08 GMT+12        Match    1917443
# 2354  2023/2024  22/07/23  Saturday  11:21:08 GMT+12        Match    1917443
# 2355  2023/2024  22/07/23  Saturday  11:21:08 GMT+12        Match    1917443
# 2356  2023/2024  22/07/23  Saturday  11:21:08 GMT+12        Match    1917443
#
# ...

# %%
df9 = pd.read_excel('PossessionSummary_Match_June_10.xlsx')
df9.columns=df9.iloc[5]
df9=df9[6:492]
df9
# Out:
# 5       Season      Date   Weekday       Start Time Session Type Session Id  \
# 6    2023/2024  10/06/23  Saturday  11:18:27 GMT+12        Match    1858858
# 7    2023/2024  10/06/23  Saturday  11:18:27 GMT+12        Match    1858858
# 8    2023/2024  10/06/23  Saturday  11:18:27 GMT+12        Match    1858858
# 9    2023/2024  10/06/23  Saturday  11:18:27 GMT+12        Match    1858858
# 10   2023/2024  10/06/23  Saturday  11:18:27 GMT+12        Match    1858858
# ..         ...       ...       ...              ...          ...        ...
# 487  2023/2024  10/06/23  Saturday  11:18:27 GMT+12        Match    1858858
# 488  2023/2024  10/06/23  Saturday  11:18:27 GMT+12        Match    1858858
# 489  2023/2024  10/06/23  Saturday  11:18:27 GMT+12        Match    1858858
# 490  2023/2024  10/06/23  Saturday  11:18:27 GMT+12        Match    1858858
# 491  2023/2024  10/06/23  Saturday  11:18:27 GMT+12        Match    1858858
#
# ...

# %%
df10 = pd.read_excel('PossessionSummary_Match_June_24.xlsx')
df10.columns=df10.iloc[5]
df10=df10[6:1659]
df10
# Out:
# 5        Season      Date   Weekday       Start Time Session Type Session Id  \
# 6     2023/2024  24/06/23  Saturday  11:16:52 GMT+12        Match    1880129
# 7     2023/2024  24/06/23  Saturday  11:16:52 GMT+12        Match    1880129
# 8     2023/2024  24/06/23  Saturday  11:16:52 GMT+12        Match    1880129
# 9     2023/2024  24/06/23  Saturday  11:16:52 GMT+12        Match    1880129
# 10    2023/2024  24/06/23  Saturday  11:16:52 GMT+12        Match    1880129
# ...         ...       ...       ...              ...          ...        ...
# 1654  2023/2024  24/06/23  Saturday  11:16:52 GMT+12        Match    1880129
# 1655  2023/2024  24/06/23  Saturday  11:16:52 GMT+12        Match    1880129
# 1656  2023/2024  24/06/23  Saturday  11:16:52 GMT+12        Match    1880129
# 1657  2023/2024  24/06/23  Saturday  11:16:52 GMT+12        Match    1880129
# 1658  2023/2024  24/06/23  Saturday  11:16:52 GMT+12        Match    1880129
#
# ...

# %%
df11 = pd.read_excel('PossessionSummary_Match_March_04.xlsx')
df11.columns=df11.iloc[5]
df11=df11[6:608]
df11
# Out:
# 5       Season      Date   Weekday       Start Time Session Type Session Id  \
# 6    2023/2024  04/03/23  Saturday  11:20:54 GMT+13        Match    1605997
# 7    2023/2024  04/03/23  Saturday  11:20:54 GMT+13        Match    1605997
# 8    2023/2024  04/03/23  Saturday  11:20:54 GMT+13        Match    1605997
# 9    2023/2024  04/03/23  Saturday  11:20:54 GMT+13        Match    1605997
# 10   2023/2024  04/03/23  Saturday  11:20:54 GMT+13        Match    1605997
# ..         ...       ...       ...              ...          ...        ...
# 603  2023/2024  04/03/23  Saturday  11:20:54 GMT+13        Match    1605997
# 604  2023/2024  04/03/23  Saturday  11:20:54 GMT+13        Match    1605997
# 605  2023/2024  04/03/23  Saturday  11:20:54 GMT+13        Match    1605997
# 606  2023/2024  04/03/23  Saturday  11:20:54 GMT+13        Match    1605997
# 607  2023/2024  04/03/23  Saturday  11:20:54 GMT+13        Match    1605997
#
# ...

# %%
df12 = pd.read_excel('PossessionSummary_Match_March_12.xlsx')
df12.columns=df12.iloc[5]
df12=df12[6:1642]
df12
# Out:
# 5        Season      Date Weekday       Start Time Session Type Session Id  \
# 6     2023/2024  12/03/23  Sunday  15:28:58 GMT+13        Match    1632965
# 7     2023/2024  12/03/23  Sunday  15:28:58 GMT+13        Match    1632965
# 8     2023/2024  12/03/23  Sunday  15:28:58 GMT+13        Match    1632965
# 9     2023/2024  12/03/23  Sunday  15:28:58 GMT+13        Match    1632965
# 10    2023/2024  12/03/23  Sunday  15:28:58 GMT+13        Match    1632965
# ...         ...       ...     ...              ...          ...        ...
# 1637  2023/2024  12/03/23  Sunday  15:28:58 GMT+13        Match    1632965
# 1638  2023/2024  12/03/23  Sunday  15:28:58 GMT+13        Match    1632965
# 1639  2023/2024  12/03/23  Sunday  15:28:58 GMT+13        Match    1632965
# 1640  2023/2024  12/03/23  Sunday  15:28:58 GMT+13        Match    1632965
# 1641  2023/2024  12/03/23  Sunday  15:28:58 GMT+13        Match    1632965
#
# ...

# %%
df13 = pd.read_excel('PossessionSummary_Match_March_25.xlsx')
df13.columns=df13.iloc[5]
df13=df13[6:448]
df13
# Out:
# 5       Season      Date   Weekday       Start Time Session Type Session Id  \
# 6    2023/2024  25/03/23  Saturday  11:26:24 GMT+13        Match    1665395
# 7    2023/2024  25/03/23  Saturday  11:26:24 GMT+13        Match    1665395
# 8    2023/2024  25/03/23  Saturday  11:26:24 GMT+13        Match    1665395
# 9    2023/2024  25/03/23  Saturday  11:26:24 GMT+13        Match    1665395
# 10   2023/2024  25/03/23  Saturday  11:26:24 GMT+13        Match    1665395
# ..         ...       ...       ...              ...          ...        ...
# 443  2023/2024  25/03/23  Saturday  11:26:24 GMT+13        Match    1665395
# 444  2023/2024  25/03/23  Saturday  11:26:24 GMT+13        Match    1665395
# 445  2023/2024  25/03/23  Saturday  11:26:24 GMT+13        Match    1665395
# 446  2023/2024  25/03/23  Saturday  11:26:24 GMT+13        Match    1665395
# 447  2023/2024  25/03/23  Saturday  11:26:24 GMT+13        Match    1665395
#
# ...

# %%
df14 = pd.read_excel('PossessionSummary_Match_May_20.xlsx')
df14.columns=df14.iloc[5]
df14=df14[6:658]
df14
# Out:
# 5       Season      Date   Weekday       Start Time Session Type Session Id  \
# 6    2023/2024  20/05/23  Saturday  14:26:24 GMT+12        Match    1819196
# 7    2023/2024  20/05/23  Saturday  14:26:24 GMT+12        Match    1819196
# 8    2023/2024  20/05/23  Saturday  14:26:24 GMT+12        Match    1819196
# 9    2023/2024  20/05/23  Saturday  14:26:24 GMT+12        Match    1819196
# 10   2023/2024  20/05/23  Saturday  14:26:24 GMT+12        Match    1819196
# ..         ...       ...       ...              ...          ...        ...
# 653  2023/2024  20/05/23  Saturday  14:26:24 GMT+12        Match    1819196
# 654  2023/2024  20/05/23  Saturday  14:26:24 GMT+12        Match    1819196
# 655  2023/2024  20/05/23  Saturday  14:26:24 GMT+12        Match    1819196
# 656  2023/2024  20/05/23  Saturday  14:26:24 GMT+12        Match    1819196
# 657  2023/2024  20/05/23  Saturday  14:26:24 GMT+12        Match    1819196
#
# ...

# %%
df15 = pd.read_excel('PossessionSummary_Match_May_27.xlsx')
df15.columns=df15.iloc[5]
df15=df15[6:502]
df15
# Out:
# 5       Season      Date   Weekday       Start Time Session Type Session Id  \
# 6    2023/2024  27/05/23  Saturday  14:25:44 GMT+12        Match    1834154
# 7    2023/2024  27/05/23  Saturday  14:25:44 GMT+12        Match    1834154
# 8    2023/2024  27/05/23  Saturday  14:25:44 GMT+12        Match    1834154
# 9    2023/2024  27/05/23  Saturday  14:25:44 GMT+12        Match    1834154
# 10   2023/2024  27/05/23  Saturday  14:25:44 GMT+12        Match    1834154
# ..         ...       ...       ...              ...          ...        ...
# 497  2023/2024  27/05/23  Saturday  14:25:44 GMT+12        Match    1834154
# 498  2023/2024  27/05/23  Saturday  14:25:44 GMT+12        Match    1834154
# 499  2023/2024  27/05/23  Saturday  14:25:44 GMT+12        Match    1834154
# 500  2023/2024  27/05/23  Saturday  14:25:44 GMT+12        Match    1834154
# 501  2023/2024  27/05/23  Saturday  14:25:44 GMT+12        Match    1834154
#
# ...

# %%
datasets=[df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15]
df16 = pd.concat(datasets)
df16
# Out:
# 5       Season      Date   Weekday       Start Time Session Type Session Id  \
# 6    2023/2024  01/04/23  Saturday  14:48:39 GMT+13        Match    1687019
# 7    2023/2024  01/04/23  Saturday  14:48:39 GMT+13        Match    1687019
# 8    2023/2024  01/04/23  Saturday  14:48:39 GMT+13        Match    1687019
# 9    2023/2024  01/04/23  Saturday  14:48:39 GMT+13        Match    1687019
# 10   2023/2024  01/04/23  Saturday  14:48:39 GMT+13        Match    1687019
# ..         ...       ...       ...              ...          ...        ...
# 497  2023/2024  27/05/23  Saturday  14:25:44 GMT+12        Match    1834154
# 498  2023/2024  27/05/23  Saturday  14:25:44 GMT+12        Match    1834154
# 499  2023/2024  27/05/23  Saturday  14:25:44 GMT+12        Match    1834154
# 500  2023/2024  27/05/23  Saturday  14:25:44 GMT+12        Match    1834154
# 501  2023/2024  27/05/23  Saturday  14:25:44 GMT+12        Match    1834154
#
# ...

# %%
df16.to_excel(r'C:\Users\ASUS\Desktop\D. STEM PROJECT\posssesionndataset.xlsx')
df16.columns.tolist()
# Out:
# ['Season',
#  'Date',
#  'Weekday',
#  'Start Time',
#  'Session Type',
#  'Session Id',
#  'Phase Type',
#  'Tag',
#  'Phase Id',
#  'Phase Start Time',
#  'Phase Duration (min)',
#  'Participated Players',
#  'Player Name',
#  'Position Category',
#  'Position',
#  'Possession Time (min from phase start)',
#  'Possession Type',
#  'Time to Release (sec)',
#  'Receiving Leg',
#  'Releasing Leg',
#  'Release Foot Zone',
#  'Release Velocity (m/sec)']

# %%
# Find and display null values in the DataFrame
null_df = df16.isnull()
print("\nNull Values in the DataFrame:")
print(null_df)

# Delete rows with null values
df17 = df16.dropna()
print("\nDataFrame after Deleting Rows with Null Values:")
print(df17)
# Out:
# Null Values in the DataFrame:
# 5    Season   Date  Weekday  Start Time  Session Type  Session Id  Phase Type  \
# 6     False  False    False       False         False       False       False
# 7     False  False    False       False         False       False       False
# 8     False  False    False       False         False       False       False
# 9     False  False    False       False         False       False       False
# 10    False  False    False       False         False       False       False
# ..      ...    ...      ...         ...           ...         ...         ...
# 497   False  False    False       False         False       False       False
# 498   False  False    False       False         False       False       False
# 499   False  False    False       False         False       False       False
# 500   False  False    False       False         False       False       False
# 501   False  False    False       False         False       False       False
#
# ...
