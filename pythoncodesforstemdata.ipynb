# %%
# Libraries
import pandas as pd
import numpy as np

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import f_oneway
from scipy.stats import chi2_contingency

from sklearn.utils import resample
import statsmodels.api as sm;
import scipy;
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA


'''Font colors'''
#from pyfiglet import Figlet
#from termcolor import colored


#''Extra Libraries''

from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.linear_model import LogisticRegression
#from sklearn.linear_model import RandomizedLasso,LassoLarsCV
from sklearn.exceptions import ConvergenceWarning 
from sklearn.model_selection import train_test_split
from sklearn.metrics import make_scorer, accuracy_score, confusion_matrix
import sklearn.datasets 
'''Scipy, Stats Library'''
from scipy.stats import skew
''' To Ignore Warning'''
import warnings
warnings.filterwarnings('ignore')
''' To Do : Inline Priting of Visualizations '''
sns.set()
# %matplotlib inline

# %%
df1 = pd.read_excel('EliteExtras_Match_April_01.xlsx')
df1.columns=df1.iloc[6]
df1=df1[7:47]
df1
df2 = pd.read_excel('Unite_Match_April_01.xlsx')
df2.columns=df2.iloc[6]
df2=df2[7:47]
df2
df3 = pd.merge(df1, df2)
df3.columns.tolist()
# Out:
# ['Season',
#  'Date',
#  'Day',
#  'Session Id',
#  'Session Type',
#  'Phase Id',
#  'Phase Type',
#  'Tag',
#  'Phase Start Time',
#  'Phase Duration (min)',
#  'Match Opponent',
#  'Match Competition',
#  'Match Venue',
#  'Participated Players',
#  'Format',
#  'Intensity',
#  'Field Size(m)',
#  'Player Name',
#  'Age Group',
#  'Player Type',
#  'Dominant Leg',
#  'Height (cm)',
#  'Weight (Kg)',
#  'Date of Birth',
#  'Year of Birth',
#  'Position Category',
#  'Position',
#  'Player Participation Time (min)',
#  'Turn Count',
#  'Turn Count with the Ball',
#  'Turn Count without the Ball',
#  'Total Turn Intensity',
#  'Total Turn Intensity with the Ball',
#  'Total Turn Intensity without the Ball',
#  'Medium Right - Turn Count',
#  'Medium Right - Turn Count with the Ball',
#  'Medium Right - Turn Count without the Ball',
#  'Medium Right - Total Turn Intensity',
#  'Medium Right - Total Turn Intensity with the Ball',
# ...

# %%
df4 = pd.read_excel('EliteExtras_Match_April_07.xlsx')
df4.columns=df4.iloc[6]
df4=df4[7:45]
df4
# Out:
# 6      Season                 Date     Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 8   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 9   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 10  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 11  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 12  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 13  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 14  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 15  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 16  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 17  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# ...

# %%
df5 = pd.read_excel('Unite_Match_April_07.xlsx')
df5.columns=df5.iloc[6]
df5=df5[7:47]
df5
# Out:
# 6      Season                 Date     Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 8   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 9   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 10  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 11  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 12  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 13  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 14  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 15  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 16  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 17  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# ...

# %%
df6 = pd.merge(df4, df5)
df6
# Out:
# 6      Season                 Date     Day Session Id Session Type Phase Id  \
# 0   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 1   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 2   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 3   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 4   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 5   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 6   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 7   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 8   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 9   2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# 10  2023/2024  2023-04-07 00:00:00  Friday    1705066        Match  1705066
# ...

# %%
df7 = pd.read_excel('EliteExtras_Match_April_22.xlsx')
df7.columns=df7.iloc[6]
df7=df7[7:50]
df7
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 8   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 9   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 10  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 11  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 12  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 13  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 14  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 15  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 16  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 17  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# ...

# %%
df8 = pd.read_excel('Unite_Match_April_22.xlsx')
df8.columns=df8.iloc[6]
df8=df8[7:50]
df8
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 8   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 9   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 10  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 11  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 12  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 13  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 14  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 15  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 16  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 17  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# ...

# %%
df9 = pd.merge(df7, df8)
df9
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 0   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 1   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 2   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 3   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 4   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 5   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 6   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 7   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 8   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 9   2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# 10  2023/2024  2023-04-22 00:00:00  Saturday    1743402        Match  1743402
# ...

# %%
df10 = pd.read_excel('EliteExtras_Match_April_29.xlsx')
df10.columns=df10.iloc[6]
df10=df10[7:49]
df10
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 8   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 9   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 10  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 11  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 12  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 13  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 14  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 15  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 16  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 17  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# ...

# %%
df11 = pd.read_excel('Unite_Match_April_29.xlsx')
df11.columns=df11.iloc[6]
df11=df11[7:49]
df11
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 8   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 9   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 10  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 11  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 12  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 13  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 14  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 15  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 16  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 17  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# ...

# %%
df12=pd.merge(df10, df11)
df12
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 0   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 1   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 2   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 3   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 4   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 5   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 6   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 7   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 8   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 9   2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# 10  2023/2024  2023-04-29 00:00:00  Saturday    1764288        Match  1764288
# ...

# %%
df13 = pd.read_excel('EliteExtras_Match_February_26.xlsx')
df13.columns=df13.iloc[6]
df13=df13[7:58]
df13
# Out:
# 6      Season                 Date     Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 8   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 9   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 10  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 11  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 12  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 13  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 14  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 15  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 16  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 17  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# ...

# %%
df14 = pd.read_excel('Unite_Match_February_26.xlsx')
df14.columns=df14.iloc[6]
df14=df14[7:58]
df14
# Out:
# 6      Season                 Date     Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 8   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 9   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 10  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 11  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 12  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 13  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 14  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 15  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 16  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 17  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# ...

# %%
df15 = pd.merge(df13, df14)
df15
# Out:
# 6      Season                 Date     Day Session Id Session Type Phase Id  \
# 0   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 1   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 2   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 3   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 4   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 5   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 6   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 7   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 8   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 9   2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# 10  2023/2024  2023-02-26 00:00:00  Sunday    1591184        Match  1591184
# ...

# %%
df16 = pd.read_excel('EliteExtras_Match_July_01.xlsx')
df16.columns=df16.iloc[6]
df16=df16[7:40]
df16
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 8   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 9   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 10  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 11  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 12  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 13  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 14  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 15  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 16  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 17  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# ...

# %%
df17 = pd.read_excel('Unite_Match_July_01.xlsx')
df17.columns=df17.iloc[6]
df17=df17[7:40]
df17
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 8   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 9   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 10  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 11  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 12  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 13  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 14  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 15  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 16  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 17  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# ...

# %%
df18=pd.merge(df16, df17)
df18
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 0   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 1   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 2   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 3   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 4   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 5   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 6   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 7   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 8   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 9   2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# 10  2023/2024  2023-07-01 00:00:00  Saturday    1889056        Match  1889056
# ...

# %%
df19 = pd.read_excel('EliteExtras_Match_July_14.xlsx')
df19.columns=df19.iloc[6]
df19=df19[7:46]
df19
# Out:
# 6      Season                 Date     Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 8   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 9   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 10  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 11  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 12  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 13  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 14  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 15  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 16  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 17  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# ...

# %%
df20 = pd.read_excel('Unite_Match_July_14.xlsx')
df20.columns=df20.iloc[6]
df20=df20[7:46]
df20
# Out:
# 6      Season                 Date     Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 8   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 9   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 10  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 11  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 12  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 13  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 14  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 15  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 16  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 17  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# ...

# %%
df21 = pd.merge(df19, df20)
df21
# Out:
# 6      Season                 Date     Day Session Id Session Type Phase Id  \
# 0   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 1   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 2   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 3   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 4   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 5   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 6   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 7   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 8   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 9   2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# 10  2023/2024  2023-07-14 00:00:00  Friday    1905337        Match  1905337
# ...

# %%
df22 = pd.read_excel('EliteExtras_Match_July_22.xlsx')
df22.columns=df22.iloc[6]
df22=df22[7:62]
df22
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 8   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 9   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 10  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 11  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 12  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 13  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 14  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 15  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 16  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 17  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# ...

# %%
df23 = pd.read_excel('Unite_Match_July_22.xlsx')
df23.columns=df23.iloc[6]
df23=df23[7:62]
df23
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 8   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 9   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 10  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 11  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 12  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 13  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 14  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 15  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 16  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 17  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# ...

# %%
df24 = pd.merge(df22, df23)
df24
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 0   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 1   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 2   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 3   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 4   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 5   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 6   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 7   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 8   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 9   2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# 10  2023/2024  2023-07-22 00:00:00  Saturday    1917443        Match  1917443
# ...

# %%
df25 = pd.read_excel('EliteExtras_Match_June_10.xlsx')
df25.columns=df25.iloc[6]
df25=df25[7:47]
df25
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 8   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 9   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 10  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 11  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 12  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 13  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 14  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 15  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 16  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 17  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# ...

# %%
df26= pd.read_excel('Unite_Match_June_10.xlsx')
df26.columns=df26.iloc[6]
df26=df26[7:47]
df26
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 8   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 9   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 10  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 11  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 12  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 13  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 14  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 15  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 16  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 17  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# ...

# %%
df27 = pd.merge(df25, df26)
df27
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 0   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 1   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 2   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 3   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 4   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 5   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 6   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 7   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 8   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 9   2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# 10  2023/2024  2023-06-10 00:00:00  Saturday    1858858        Match  1858858
# ...

# %%
df28 = pd.read_excel('EliteExtras_Match_June_24.xlsx')
df28.columns=df28.iloc[6]
df28=df28[7:63]
df28
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 8   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 9   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 10  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 11  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 12  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 13  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 14  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 15  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 16  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 17  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# ...

# %%
df29= pd.read_excel('Unite_Match_June_24.xlsx')
df29.columns=df29.iloc[6]
df29=df29[7:63]
df29
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 8   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 9   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 10  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 11  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 12  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 13  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 14  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 15  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 16  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 17  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# ...

# %%
df30 = pd.merge(df28, df29)
df30
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 0   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 1   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 2   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 3   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 4   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 5   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 6   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 7   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 8   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 9   2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# 10  2023/2024  2023-06-24 00:00:00  Saturday    1880129        Match  1880129
# ...

# %%
df31 = pd.read_excel('EliteExtras_Match_March_04.xlsx')
df31.columns=df31.iloc[6]
df31=df31[7:49]
df31
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 8   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 9   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 10  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 11  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 12  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 13  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 14  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 15  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 16  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 17  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# ...

# %%
df32= pd.read_excel('Unite_Match_March_04.xlsx')
df32.columns=df32.iloc[6]
df32=df32[7:49]
df32
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 8   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 9   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 10  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 11  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 12  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 13  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 14  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 15  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 16  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 17  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# ...

# %%
df33 = pd.merge(df31, df32)
df33
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 0   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 1   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 2   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 3   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 4   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 5   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 6   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 7   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 8   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 9   2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# 10  2023/2024  2023-03-04 00:00:00  Saturday    1605997        Match  1605997
# ...

# %%
df34 = pd.read_excel('EliteExtras_Match_March_12.xlsx')
df34.columns=df34.iloc[6]
df34=df34[7:66]
df34
# Out:
# 6      Season                 Date     Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 8   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 9   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 10  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 11  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 12  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 13  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 14  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 15  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 16  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 17  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# ...

# %%
df35= pd.read_excel('Unite_Match_March_12.xlsx')
df35.columns=df35.iloc[6]
df35=df35[7:66]
df35
# Out:
# 6      Season                 Date     Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 8   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 9   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 10  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 11  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 12  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 13  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 14  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 15  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 16  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 17  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# ...

# %%
df36 = pd.merge(df34, df35)
df36
# Out:
# 6      Season                 Date     Day Session Id Session Type Phase Id  \
# 0   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 1   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 2   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 3   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 4   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 5   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 6   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 7   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 8   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 9   2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# 10  2023/2024  2023-03-12 00:00:00  Sunday    1632965        Match  1632965
# ...

# %%
df37 = pd.read_excel('EliteExtras_Match_March_25.xlsx')
df37.columns=df37.iloc[6]
df37=df37[7:49]
df37
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 8   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 9   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 10  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 11  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 12  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 13  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 14  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 15  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 16  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 17  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# ...

# %%
df38= pd.read_excel('Unite_Match_March_25.xlsx')
df38.columns=df38.iloc[6]
df38=df38[7:49]
df38
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 8   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 9   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 10  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 11  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 12  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 13  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 14  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 15  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 16  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 17  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# ...

# %%
df39 = pd.merge(df37, df38)
df39
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 0   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 1   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 2   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 3   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 4   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 5   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 6   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 7   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 8   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 9   2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# 10  2023/2024  2023-03-25 00:00:00  Saturday    1665395        Match  1665395
# ...

# %%
df40 = pd.read_excel('EliteExtras_Match_May_20.xlsx')
df40.columns=df40.iloc[6]
df40=df40[7:47]
df40
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 8   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 9   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 10  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 11  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 12  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 13  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 14  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 15  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 16  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 17  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# ...

# %%
df41= pd.read_excel('Unite_Match_May_20.xlsx')
df41.columns=df41.iloc[6]
df41=df41[7:47]
df41
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 8   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 9   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 10  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 11  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 12  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 13  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 14  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 15  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 16  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 17  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# ...

# %%
df42 = pd.merge(df40, df41)
df42
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 0   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 1   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 2   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 3   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 4   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 5   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 6   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 7   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 8   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 9   2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# 10  2023/2024  2023-05-20 00:00:00  Saturday    1819196        Match  1819196
# ...

# %%
df43 = pd.read_excel('EliteExtras_Match_May_27.xlsx')
df43.columns=df43.iloc[6]
df43=df43[7:47]
df43
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 8   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 9   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 10  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 11  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 12  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 13  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 14  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 15  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 16  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 17  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# ...

# %%
df44= pd.read_excel('Unite_Match_May_27.xlsx')
df44.columns=df44.iloc[6]
df44=df44[7:47]
df44
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 7   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 8   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 9   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 10  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 11  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 12  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 13  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 14  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 15  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 16  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 17  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# ...

# %%
df45 = pd.merge(df43, df44)
df45
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 0   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 1   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 2   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 3   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 4   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 5   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 6   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 7   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 8   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 9   2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# 10  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834154
# ...

# %%
datasetstot=[df3, df6, df9, df12, df15, df18, df21, df24, df27, df30, df33, df36, df39, df42, df45]

# %%
df46 = pd.concat(datasetstot)
df46
# Out:
# 6      Season                 Date       Day Session Id Session Type Phase Id  \
# 0   2023/2024  2023-04-01 00:00:00  Saturday    1687019        Match  1687019
# 1   2023/2024  2023-04-01 00:00:00  Saturday    1687019        Match  1687019
# 2   2023/2024  2023-04-01 00:00:00  Saturday    1687019        Match  1687019
# 3   2023/2024  2023-04-01 00:00:00  Saturday    1687019        Match  1687019
# 4   2023/2024  2023-04-01 00:00:00  Saturday    1687019        Match  1687019
# ..        ...                  ...       ...        ...          ...      ...
# 35  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834218
# 36  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834218
# 37  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834218
# 38  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834218
# 39  2023/2024  2023-05-27 00:00:00  Saturday    1834154        Match  1834218
#
# ...

# %%
df46.to_excel(r'C:\Users\ASUS\Desktop\D. STEM PROJECT\eliteplayerdataset.xlsx' )

# %%
df = pd.read_excel(r'C:\Users\ASUS\Desktop\D. STEM PROJECT\eliteplayerdataset.xlsx')
df
# Out:
#      Unnamed: 0     Season       Date       Day  Session Id Session Type  \
# 0             0  2023/2024 2023-04-01  Saturday     1687019        Match
# 1             1  2023/2024 2023-04-01  Saturday     1687019        Match
# 2             2  2023/2024 2023-04-01  Saturday     1687019        Match
# 3             3  2023/2024 2023-04-01  Saturday     1687019        Match
# 4             4  2023/2024 2023-04-01  Saturday     1687019        Match
# ..          ...        ...        ...       ...         ...          ...
# 655          35  2023/2024 2023-05-27  Saturday     1834154        Match
# 656          36  2023/2024 2023-05-27  Saturday     1834154        Match
# 657          37  2023/2024 2023-05-27  Saturday     1834154        Match
# 658          38  2023/2024 2023-05-27  Saturday     1834154        Match
# 659          39  2023/2024 2023-05-27  Saturday     1834154        Match
#
#      Phase Id  Phase Type              Tag Phase Start Time  ...  \
# ...

# %%
# Instantiate the KNN imputer with the desired number of neighbors (e.g., 5)
knn_imputer = KNNImputer(n_neighbors=5)

# Apply KNN imputation to the entire dataset
data_imputed = knn_imputer.fit_transform(df)

# Convert the imputed data back to a DataFrame with the same column names
data_imputed_df = pd.DataFrame(data_imputed, columns=df.columns)

# Save the imputed dataset to a new CSV file
data_imputed_df.to_excel(r'C:\Users\ASUS\Desktop\D. STEM PROJECT\eliteplayerdatasedata_imputed_df.xlsx', index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5036\241627034.py in <module>
#       3
#       4 # Apply KNN imputation to the entire dataset
# ----> 5 data_imputed = knn_imputer.fit_transform(df)
#       6
#       7 # Convert the imputed data back to a DataFrame with the same column names
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_knn.py in fit(self, X, y)
#     207             )
#     208
# --> 209         X = self._validate_data(
# ...

# %%
df46_imputed.to_csv(r'C:\Users\ASUS\Desktop\D. STEM PROJECT\eliteplayerdataset.csv' )
